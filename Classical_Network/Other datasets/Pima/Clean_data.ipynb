# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

# %%
raw = pd.read_csv("diabetes.csv")
test = raw[raw['Insulin']!=0]
test2 = test[test['Glucose']!=0]
data = test2[test['BMI']!=0]

data.to_csv(f'diabetes_final.csv')
# Out:
# /tmp/ipykernel_1299440/3188150904.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = test2[test['BMI']!=0]

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 755            1      128             88             39      110  36.5
# 760            2       88             58             26       16  28.4
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# 4                       2.288   33        1
# 6                       0.248   26        1
# 8                       0.158   53        1
# 13                      0.398   59        1
# ..                        ...  ...      ...
# 753                     0.222   26        1
# 755                     1.057   37        1
# 760                     0.766   22        0
# 763                     0.171   63        0
# 765                     0.245   30        0
#
# [392 rows x 9 columns]
