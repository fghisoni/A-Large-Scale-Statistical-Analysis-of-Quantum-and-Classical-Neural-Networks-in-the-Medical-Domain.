# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
qnn_test_accs_train_lay1_mean = []
qnn_test_accs_train_lay1_std = []

for t_size in [1,3,5,7,10]:
    int_list_tsize_qnn = []
    for seed in range(1,11):
        if t_size == 1:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep1_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 2:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep2_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 3:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep3_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 4 or t_size == 5:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep5_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 6:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep6_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 7:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep7_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 8:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep10_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 9:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep11_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 10:
            fname = f'Cross_Entropy_DataReuploading/test_acc_1layers_batchsize64_stocstep10_{seed}seed_{t_size/10}trainsize_CE_4.txt'

        with open(fname,'r') as f:
            int_list_tsize_qnn.append(float(f.readlines()[-1]))
    qnn_test_accs_train_lay1_mean.append(np.mean(np.array(int_list_tsize_qnn)))
    qnn_test_accs_train_lay1_std.append(np.std(np.array(int_list_tsize_qnn)))

# %%
qnn_test_accs_train_lay4_mean = []
qnn_test_accs_train_lay4_std = []

for t_size in [1,3,5,7,10]:
    int_list_tsize_qnn = []
    for seed in range(1,11):
        if t_size == 1:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep1_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 2:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep2_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 3:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep3_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 4 or t_size == 5:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep5_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 6:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep6_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 7:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep7_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 8:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep10_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 9:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep11_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 10:
            fname = f'Cross_Entropy_DataReuploading/test_acc_4layers_batchsize64_stocstep10_{seed}seed_{t_size/10}trainsize_CE_4.txt'

        with open(fname,'r') as f:
            int_list_tsize_qnn.append(float(f.readlines()[-1]))
    qnn_test_accs_train_lay4_mean.append(np.mean(np.array(int_list_tsize_qnn)))
    qnn_test_accs_train_lay4_std.append(np.std(np.array(int_list_tsize_qnn)))

# %%
qnn_test_accs_train_lay9_mean = []
qnn_test_accs_train_lay9_std = []

for t_size in [1,3,5,7,10]:
    int_list_tsize_qnn = []
    for seed in range(1,11):
        if t_size == 1:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep1_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 2:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep2_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 3:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep3_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 4 or t_size == 5:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep5_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 6:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep6_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 7:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep7_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 8:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep10_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 9:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep11_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        elif t_size == 10:
            fname = f'Cross_Entropy_DataReuploading/test_acc_9layers_batchsize64_stocstep10_{seed}seed_{t_size/10}trainsize_CE_4.txt'
        
        with open(fname,'r') as f:
            int_list_tsize_qnn.append(float(f.readlines()[-1]))

        
    qnn_test_accs_train_lay9_mean.append(np.mean(np.array(int_list_tsize_qnn)))
    qnn_test_accs_train_lay9_std.append(np.std(np.array(int_list_tsize_qnn)))

# %%
qnn_test_accs_train_dropout_1lay_mean = []
qnn_test_accs_train_dropout_1lay_std = []

for t_size in [1,3,5,7]:
    int_list_tsize_qnn = []
    for seed in range(1,11):
        if t_size == 1:
            fname = f'Cross_Entropy_Dropout/test_acc_1layers_batchsize64_stocstep1_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 3:
            fname = f'Cross_Entropy_Dropout/test_acc_1layers_batchsize64_stocstep3_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 5:
            fname = f'Cross_Entropy_Dropout/test_acc_1layers_batchsize64_stocstep5_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 7:
            fname = f'Cross_Entropy_Dropout/test_acc_1layers_batchsize64_stocstep7_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 10:
            fname = f'Cross_Entropy_Dropout/test_acc_1layers_batchsize64_stocstep10_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        
        with open(fname,'r') as f:
            int_list_tsize_qnn.append(float(f.readlines()[-1]))

        
    qnn_test_accs_train_dropout_1lay_mean.append(np.mean(np.array(int_list_tsize_qnn)))
    qnn_test_accs_train_dropout_1lay_std.append(np.std(np.array(int_list_tsize_qnn)))

qnn_test_accs_train_dropout_1lay_mean.append(0.8449275719999999)
qnn_test_accs_train_dropout_1lay_std.append(0.0008982631334937252)

# %%
qnn_test_accs_train_dropout_6lay_mean = []
qnn_test_accs_train_dropout_6lay_std = []

for t_size in [1,3,5,7]:
    int_list_tsize_qnn = []
    for seed in range(1,11):
        if t_size == 1:
            fname = f'Cross_Entropy_Dropout/test_acc_6layers_batchsize64_stocstep1_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 3:
            fname = f'Cross_Entropy_Dropout/test_acc_6layers_batchsize64_stocstep3_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 5:
            fname = f'Cross_Entropy_Dropout/test_acc_6layers_batchsize64_stocstep5_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 7:
            fname = f'Cross_Entropy_Dropout/test_acc_6layers_batchsize64_stocstep7_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        elif t_size == 10:
            fname = f'Cross_Entropy_Dropout/test_acc_6layers_batchsize64_stocstep10_{seed}seed_0.010000000000000002droprate_{t_size/10}trainsize_CE.txt'
        
        with open(fname,'r') as f:
            int_list_tsize_qnn.append(float(f.readlines()[-1]))

        
    qnn_test_accs_train_dropout_6lay_mean.append(np.mean(np.array(int_list_tsize_qnn)))
    qnn_test_accs_train_dropout_6lay_std.append(np.std(np.array(int_list_tsize_qnn)))

qnn_test_accs_train_dropout_6lay_mean.append(0.874637703)
qnn_test_accs_train_dropout_6lay_std.append(0.004731928033008011)

# %%
cnn_test_accs_train_mean = []
cnn_test_accs_train_std = []

for t_size in [1,3,5,7,10]:
    int_list_tsize = []
    for seed in range(1,11):
        fname = f'Res_deep/Classical_network_{t_size/10}trainsize_testaccs_{seed}seed_3layers_525252nodes_Adam.txt'
        with open(fname,'r') as f:
            int_list_tsize.append(float(f.readlines()[-1]))
    cnn_test_accs_train_mean.append(np.mean(np.array(int_list_tsize)))
    cnn_test_accs_train_std.append(np.std(np.array(int_list_tsize)))

# %%
perceptron_test_accs_train_mean = []
perceptron_test_accs_train_std = []

for t_size in [1,3,5,7,10]:
    int_list_tsize = []
    for seed in range(1,11):
        fname = f'Res_deep/Classical_network_{t_size/10}trainsize_testaccs_{seed}seed_0layers_nodes_Adam.txt'
        with open(fname,'r') as f:
            int_list_tsize.append(float(f.readlines()[-1]))
    perceptron_test_accs_train_mean.append(np.mean(np.array(int_list_tsize)))
    perceptron_test_accs_train_std.append(np.std(np.array(int_list_tsize)))

# %%
xgboost_results_mean = [0.807609, 
                        0.843841,
                        0.856522,
                        0.856884,
                        0.854347]

xgboost_results_std = [0.02, 
                        0.02,
                        0.01,
                        0.01,
                        0.004]

# %%
colors = ['#aadce0',
 '#ef8a47',
 '#376795',
 '#f7aa58',
 '#72bcd5',
 '#ffe6b7',
 '#e76254',
 '#1e466e',
 '#ffd06f',
 '#528fad']

# %%
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.sans-serif": "Palatino",})

t_size_list = [i/10 for i in [1,3,5,7,10]]

plt.plot(t_size_list, np.array(cnn_test_accs_train_mean), 'o', color = colors[1])
plt.plot(t_size_list, np.array(perceptron_test_accs_train_mean), 'o', color = colors[6])
plt.plot(t_size_list, np.array(qnn_test_accs_train_lay1_mean), 'o', color = colors[0])
plt.plot(t_size_list, np.array(qnn_test_accs_train_lay4_mean), 'o', color = colors[4])
plt.plot(t_size_list, np.array(qnn_test_accs_train_lay9_mean), 'o', color = colors[7])
plt.plot(t_size_list, np.array(qnn_test_accs_train_dropout_1lay_mean), 'o', color = colors[8])
plt.plot(t_size_list, np.array(qnn_test_accs_train_dropout_6lay_mean), 'o', color = colors[5])
plt.plot(t_size_list, np.array(xgboost_results_mean), 'o', color = 'black')


plt.plot(t_size_list, np.array(cnn_test_accs_train_mean), color = colors[1], linestyle = '--')
plt.plot(t_size_list, np.array(perceptron_test_accs_train_mean), color = colors[6], linestyle = '--')
plt.plot(t_size_list, np.array(qnn_test_accs_train_lay1_mean), color=colors[0], linestyle = '--')
plt.plot(t_size_list, np.array(qnn_test_accs_train_lay4_mean), color=colors[4], linestyle = '--')
plt.plot(t_size_list, np.array(qnn_test_accs_train_lay9_mean), color=colors[7], linestyle = '--')
plt.plot(t_size_list, np.array(qnn_test_accs_train_dropout_1lay_mean), color=colors[8], linestyle = '--')
plt.plot(t_size_list, np.array(qnn_test_accs_train_dropout_6lay_mean), color=colors[5], linestyle = '--')
plt.plot(t_size_list, np.array(xgboost_results_mean), color='black', linestyle = '--')


plt.fill_between(t_size_list, np.array(cnn_test_accs_train_mean) + 1.96*np.array(cnn_test_accs_train_std)/np.sqrt(10), np.array(cnn_test_accs_train_mean) - 1.96*np.array(cnn_test_accs_train_std)/np.sqrt(10), label='Classical Neural Network', alpha = 0.5, color = colors[8])
plt.fill_between(t_size_list, np.array(perceptron_test_accs_train_mean) + 1.96*np.array(perceptron_test_accs_train_std)/np.sqrt(10), np.array(perceptron_test_accs_train_mean) - 1.96*np.array(perceptron_test_accs_train_std)/np.sqrt(10), label='Perceptron', alpha = 0.5, color = colors[6])
plt.fill_between(t_size_list, np.array(qnn_test_accs_train_lay1_mean) + 1.96*np.array(qnn_test_accs_train_lay1_std)/np.sqrt(10), np.array(qnn_test_accs_train_lay1_mean) - 1.96*np.array(qnn_test_accs_train_lay1_std)/np.sqrt(10), color = colors[0], alpha = 0.5, label = 'QNN 1 Layer')
plt.fill_between(t_size_list, np.array(qnn_test_accs_train_lay4_mean) + 1.96*np.array(qnn_test_accs_train_lay4_std)/np.sqrt(10), np.array(qnn_test_accs_train_lay4_mean) - 1.96*np.array(qnn_test_accs_train_lay4_std)/np.sqrt(10), color = colors[4], alpha = 0.5, label = 'QNN 4 Layers')
plt.fill_between(t_size_list, np.array(qnn_test_accs_train_lay9_mean) + 1.96*np.array(qnn_test_accs_train_lay9_std)/np.sqrt(10), np.array(qnn_test_accs_train_lay9_mean) - 1.96*np.array(qnn_test_accs_train_lay9_std)/np.sqrt(10), color = colors[7], alpha = 0.5, label = 'QNN 9 Layers')
plt.fill_between(t_size_list, np.array(qnn_test_accs_train_dropout_1lay_mean) + 1.96*np.array(qnn_test_accs_train_dropout_1lay_std)/np.sqrt(10), np.array(qnn_test_accs_train_dropout_1lay_mean) - 1.96*np.array(qnn_test_accs_train_dropout_1lay_std)/np.sqrt(10), color = colors[8], alpha = 0.5, label = 'QNN 1 Layer - Dropout')
plt.fill_between(t_size_list, np.array(qnn_test_accs_train_dropout_6lay_mean) + 1.96*np.array(qnn_test_accs_train_dropout_6lay_std)/np.sqrt(10), np.array(qnn_test_accs_train_dropout_6lay_mean) - 1.96*np.array(qnn_test_accs_train_dropout_6lay_std)/np.sqrt(10), color = colors[5], alpha = 0.5, label = 'QNN 6 Layer - Dropout')
plt.fill_between(t_size_list, np.array(xgboost_results_mean) + 1.96*np.array(xgboost_results_std)/np.sqrt(10), np.array(xgboost_results_mean) - 1.96*np.array(xgboost_results_std)/np.sqrt(10), color = 'black', alpha = 0.5, label = 'XGBoost')

plt.xlabel("train size", size = 14)
plt.xticks((0.1, 0.3, 0.5, 0.7, 1))
plt.ylabel("Test accuracy", size = 14)
plt.ylim((0.765, 0.88))
plt.tick_params(axis='both', labelsize =14)
plt.legend(bbox_to_anchor = (0.42,0.5875), prop={'size': 12})
plt.grid()
plt.savefig('train_size_xgboost.pdf', bbox_inches = 'tight')
